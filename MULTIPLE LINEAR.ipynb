# %%
# import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns 

#make plots inline 
# %matplotlib inline

# model preprocessors
from sklearn.model_selection import train_test_split

# model
from sklearn.linear_model import LinearRegression

# evaluation 
from sklearn.metrics import mean_absolute_error, mean_squared_error

# %%
df = pd.read_csv("data/DATASET FOR MULTIPLE.csv")
df
# Out:
#     Size (sq ft)  Number of Bedrooms  Age of House (years) Price ($)
# 0           1500                   3                    10   300,000
# 1           2500                   4                     5   500,000
# 2           1800                   3                     8   350,000
# 3           2200                   4                    12   450,000
# 4           1600                   2                    15   275,000
# 5           2000                   3                     7   400,000
# 6           3000                   5                     6   600,000
# 7           1700                   2                    20   250,000
# 8           2800                   4                     4   550,000
# 9           1900                   3                     9   375,000
# 10          2100                   4                    10   425,000
# 11          2400                   3                     3   480,000
# 12          2600                   5                     8   520,000
# 13          2300                   4                     6   460,000
# 14          3100                   5                     5   620,000
# 15          1200                   2                    25   200,000
# 16          1400                   3                    18   280,000
# 17          2700                   4                     7   530,000
# 18          2900                   5                     9   570,000
# 19          1350                   2                    22   220,000

# %%
df.dtypes
# Out:
# Size (sq ft)             int64
# Number of Bedrooms       int64
# Age of House (years)     int64
# Price ($)               object
# dtype: object

# %%
df.isna().sum()
# Out:
# Size (sq ft)            0
# Number of Bedrooms      0
# Age of House (years)    0
# Price ($)               0
# dtype: int64

# %%
df.shape
# Out:
# (20, 4)

# %%
sns.heatmap(corr)
# Out:
# <Axes: >

# %%
plt.plot(df)
plt.legend(df.columns)
plt.title("Price ($)")
# Out:
# Text(0.5, 1.0, 'Price ($)')

# %%
df["Price ($)"]=df["Price ($)"].str.replace(",","").astype(int)

# %%
df
# Out:
#     Size (sq ft)  Number of Bedrooms  Age of House (years)  Price ($)
# 0           1500                   3                    10     300000
# 1           2500                   4                     5     500000
# 2           1800                   3                     8     350000
# 3           2200                   4                    12     450000
# 4           1600                   2                    15     275000
# 5           2000                   3                     7     400000
# 6           3000                   5                     6     600000
# 7           1700                   2                    20     250000
# 8           2800                   4                     4     550000
# 9           1900                   3                     9     375000
# 10          2100                   4                    10     425000
# 11          2400                   3                     3     480000
# 12          2600                   5                     8     520000
# 13          2300                   4                     6     460000
# 14          3100                   5                     5     620000
# 15          1200                   2                    25     200000
# 16          1400                   3                    18     280000
# 17          2700                   4                     7     530000
# 18          2900                   5                     9     570000
# 19          1350                   2                    22     220000

# %%
df.dtypes
# Out:
# Size (sq ft)            int64
# Number of Bedrooms      int64
# Age of House (years)    int64
# Price ($)               int32
# dtype: object

# %%
x = df.drop("Price ($)", axis=1)

# %%
y = df["Price ($)"]

# %%
xtrain, xtest, ytrain, ytest = train_test_split(x,y,test_size=0.2)

# %%
rg = LinearRegression()

# %%
rg.fit(xtrain,ytrain)
# Out:
# LinearRegression()

# %%
rg.coef_
# Out:
# array([  156.77562042, 22574.82660885, -3525.49004838])

# %%
rg.intercept_
# Out:
# 35307.55723860103

# %%
xtest,ytest
# Out:
# (    Size (sq ft)  Number of Bedrooms  Age of House (years)
#  5           2000                   3                     7
#  16          1400                   3                    18
#  3           2200                   4                    12
#  10          2100                   4                    10,
#  5     400000
#  16    280000
#  3     450000
#  10    425000
#  Name: Price ($), dtype: int32)

# %%
ypred = rg.predict(xtest)

# %%
ypred
# Out:
# array([391904.84757086, 259059.08478542, 428207.34802226, 419580.7660768 ])

# %%
mse = mean_squared_error(ytest, ypred)
mse
# Out:
# 252085299.85309544

# %%
mae = mean_absolute_error(ytest, ypred)
mae
# Out:
# 14061.988386165584

# %%
corr = df.corr()
corr
# Out:
#                       Size (sq ft)  Number of Bedrooms  Age of House (years)  \
# Size (sq ft)              1.000000            0.887709             -0.783170
# Number of Bedrooms        0.887709            1.000000             -0.687897
# Age of House (years)     -0.783170           -0.687897              1.000000
# Price ($)                 0.986138            0.922075             -0.834882
#
#                       Price ($)
# Size (sq ft)           0.986138
# Number of Bedrooms     0.922075
# Age of House (years)  -0.834882
# Price ($)              1.000000
