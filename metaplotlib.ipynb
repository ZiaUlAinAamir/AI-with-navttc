# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
x=[1,2,3,4,5,6,7]
a= [2,9,5,9,8,9,4]
b= [2,6,5,5,8,5,4]
c= [2,3,5,1,8,1,4]
d=[3,4,7,9,1,5,6]
plt.scatter(x,a,color="navy", linestyle="--",marker="o" ,linewidth=2)
plt.bar(x,b,color="grey",linewidth=2)
plt.plot(x,c,color="green", linestyle="-.",marker="D" ,linewidth=2)
