# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data={
    'date':pd.date_range(start='2023-01-01', periods=10, freq='d'), 'sales':[11,2,13,5,17,8,20,29,21,25]}

# %%
df=pd.DataFrame(data)
df
# Out:
#         date  sales
# 0 2023-01-01     11
# 1 2023-01-02      2
# 2 2023-01-03     13
# 3 2023-01-04      5
# 4 2023-01-05     17
# 5 2023-01-06      8
# 6 2023-01-07     20
# 7 2023-01-08     29
# 8 2023-01-09     21
# 9 2023-01-10     25

# %%
df.set_index('date',inplace=True)
def apply_discount(sale):
    return sale*0.9

# %%
df['sales'].plot()
plt.title('sales and discounted sales over time')
plt.xlabel('date')
plt.ylabel('sales')
plt.show()
